# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import psycopg2
import sqlalchemy

# %%
post = 'https://t.me/tikvahethiopia/86164'

# %%
response = requests.get(post)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Telegram: Contact @tikvahethiopia</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script>try{if(window.parent!=null&&window!=window.parent){window.parent.postMessage(JSON.stringify({eventType:'web_app_open_tg_link',eventData:{path_full:"\/tikvahethiopia\/86164"}}),'https://web.telegram.org');}}catch(e){}</script>
# <meta content="TIKVAH-ETHIOPIA" property="og:title"/>
# <meta content="https://cdn4.cdn-telegram.org/file/jEUJN2otuVe2oOJdP-aj8ipSQFkBZcZHmldZT7fvC-zsA2V0loMJGmF8SE78xx-KQJytPp4Q3TtuP6kn-Dv-56B4ZkvXm2g4Kj5IZyTspKM5GdPr0JnhA9c0ideJ_B_ZfyqVazIvlf7Xc5Cw-O1l12XPL6o3edFXXX_5GE-vT9PzapHQH1MDxSuvrKFeg_clQ3WHlQMZ6wJVZRpl1FQ7q8dgnamTTemni1rOM6g0ZGrhLeu69eKWneNVAd8_n2dRh1lFoS2fetZpcnlEg3OpFu_ZiBBL2c-cLv9LPDUQdtSs3gDv1v9gHz34tox_x0eUkxIvlnercp1SBSZqJC_MoA.jpg" property="og:image"/>
# <meta content="Telegram" property="og:site_name"/>
# <meta content="መተግበሪያዎን ሲቢኢ ብር ላይ ያስቀምጡ
# በቀላሉ በርካታ ደንበኞች ዘንድ  ይድረሱ!
#
# #CBE #cbebirr #apps #digitalbanking
# *************
# የሲቢኢ ብር መተግበሪያ ማስፈንጠሪያ፡
#
# • ለአንድሮይድ ስልኮች፡ https://play.google.com/store/apps/details?id=prod.cbe.birr
# • ለአፕል ስልኮች፡ https://apps.apple.com/us/app/cbebirr/id1600841787" property="og:description"/>
# <meta content="TIKVAH-ETHIOPIA" property="twitter:title"/>
# <meta content="https://cdn4.cdn-telegram.org/file/jEUJN2otuVe2oOJdP-aj8ipSQFkBZcZHmldZT7fvC-zsA2V0loMJGmF8SE78xx-KQJytPp4Q3TtuP6kn-Dv-56B4ZkvXm2g4Kj5IZyTspKM5GdPr0JnhA9c0ideJ_B_ZfyqVazIvlf7Xc5Cw-O1l12XPL6o3edFXXX_5GE-vT9PzapHQH1MDxSuvrKFeg_clQ3WHlQMZ6wJVZRpl1FQ7q8dgnamTTemni1rOM6g0ZGrhLeu69eKWneNVAd8_n2dRh1lFoS2fetZpcnlEg3OpFu_ZiBBL2c-cLv9LPDUQdtSs3gDv1v9gHz34tox_x0eUkxIvlnercp1SBSZqJC_MoA.jpg" property="twitter:image"/>
# <meta content="@Telegram" property="twitter:site"/>
# <meta content="686449807" property="al:ios:app_store_id"/>
# <meta content="Telegram Messenger" property="al:ios:app_name"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" property="al:ios:url"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" property="al:android:url"/>
# <meta content="Telegram" property="al:android:app_name"/>
# <meta content="org.telegram.messenger" property="al:android:package"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@Telegram" name="twitter:site"/>
# <meta content="መተግበሪያዎን ሲቢኢ ብር ላይ ያስቀምጡ
# በቀላሉ በርካታ ደንበኞች ዘንድ  ይድረሱ!
#
# #CBE #cbebirr #apps #digitalbanking
# *************
# የሲቢኢ ብር መተግበሪያ ማስፈንጠሪያ፡
#
# • ለአንድሮይድ ስልኮች፡ https://play.google.com/store/apps/details?id=prod.cbe.birr
# • ለአፕል ስልኮች፡ https://apps.apple.com/us/app/cbebirr/id1600841787
# " name="twitter:description"/>
# <meta content="Telegram Messenger" name="twitter:app:name:iphone"/>
# <meta content="686449807" name="twitter:app:id:iphone"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" name="twitter:app:url:iphone"/>
# <meta content="Telegram Messenger" name="twitter:app:name:ipad"/>
# <meta content="686449807" name="twitter:app:id:ipad"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" name="twitter:app:url:ipad"/>
# <meta content="Telegram" name="twitter:app:name:googleplay"/>
# <meta content="org.telegram.messenger" name="twitter:app:id:googleplay"/>
# <meta content="https://t.me/tikvahethiopia/86164" name="twitter:app:url:googleplay"/>
# <meta content="app-id=686449807, app-argument: tg://resolve?domain=tikvahethiopia&amp;post=86164" name="apple-itunes-app"/>
# <script>window.matchMedia&&window.matchMedia('(prefers-color-scheme: dark)').matches&&document.documentElement&&document.documentElement.classList&&document.documentElement.classList.add('theme_dark');</script>
# <link href="//telegram.org/img/website_icon.svg?4" rel="icon" type="image/svg+xml"/>
# <link href="//telegram.org/img/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="//telegram.org/img/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//telegram.org/img/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//telegram.org/img/favicon.ico" rel="alternate icon" type="image/x-icon">
# <link href="//telegram.org/css/font-roboto.css?1" rel="stylesheet" type="text/css"/>
# <!--link href="/css/myriad.css" rel="stylesheet"-->
# <link href="//telegram.org/css/bootstrap.min.css?3" rel="stylesheet"/>
# <link href="//telegram.org/css/telegram.css?237" media="screen" rel="stylesheet"/>
# </link></head>
# <body class="no_transition">
# <div class="tgme_background_wrap">
# <canvas class="tgme_background default" data-colors="dbddbb,6ba587,d5d88d,88b884" height="50" id="tgme_background" width="50"></canvas>
# <div class="tgme_background_pattern default"></div>
# </div>
# <div class="tgme_page_wrap">
# <div class="tgme_head_wrap">
# <div class="tgme_head">
# <a class="tgme_head_brand" href="//telegram.org/">
# <svg class="tgme_logo" height="34" viewbox="0 0 133 34" width="133" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <circle cx="17" cy="17" fill="var(--accent-btn-color)" r="17"></circle><path d="m7.06510669 16.9258959c5.22739451-2.1065178 8.71314291-3.4952633 10.45724521-4.1662364 4.9797665-1.9157646 6.0145193-2.2485535 6.6889567-2.2595423.1483363-.0024169.480005.0315855.6948461.192827.1814076.1361492.23132.3200675.2552048.4491519.0238847.1290844.0536269.4231419.0299841.65291-.2698553 2.6225356-1.4375148 8.986738-2.0315537 11.9240228-.2513602 1.2428753-.7499132 1.5088847-1.2290685 1.5496672-1.0413153.0886298-1.8284257-.4857912-2.8369905-1.0972863-1.5782048-.9568691-2.5327083-1.3984317-4.0646293-2.3321592-1.7703998-1.0790837-.212559-1.583655.7963867-2.5529189.2640459-.2536609 4.7753906-4.3097041 4.755976-4.431706-.0070494-.0442984-.1409018-.481649-.2457499-.5678447-.104848-.0861957-.2595946-.0567202-.3712641-.033278-.1582881.0332286-2.6794907 1.5745492-7.5636077 4.6239616-.715635.4545193-1.3638349.6759763-1.9445998.6643712-.64024672-.0127938-1.87182452-.334829-2.78737602-.6100966-1.12296117-.3376271-1.53748501-.4966332-1.45976769-1.0700283.04048-.2986597.32581586-.610598.8560076-.935815z" fill="#fff"></path><path d="m49.4 24v-12.562h-4.224v-2.266h11.198v2.266h-4.268v12.562zm16.094-4.598h-7.172c.066 1.936 1.562 2.772 3.3 2.772 1.254 0 2.134-.198 2.97-.484l.396 1.848c-.924.396-2.2.682-3.74.682-3.476 0-5.522-2.134-5.522-5.412 0-2.97 1.804-5.764 5.236-5.764 3.476 0 4.62 2.86 4.62 5.214 0 .506-.044.902-.088 1.144zm-7.172-1.892h4.708c.022-.99-.418-2.618-2.222-2.618-1.672 0-2.376 1.518-2.486 2.618zm9.538 6.49v-15.62h2.706v15.62zm14.84-4.598h-7.172c.066 1.936 1.562 2.772 3.3 2.772 1.254 0 2.134-.198 2.97-.484l.396 1.848c-.924.396-2.2.682-3.74.682-3.476 0-5.522-2.134-5.522-5.412 0-2.97 1.804-5.764 5.236-5.764 3.476 0 4.62 2.86 4.62 5.214 0 .506-.044.902-.088 1.144zm-7.172-1.892h4.708c.022-.99-.418-2.618-2.222-2.618-1.672 0-2.376 1.518-2.486 2.618zm19.24-1.144v6.072c0 2.244-.462 3.85-1.584 4.862-1.1.99-2.662 1.298-4.136 1.298-1.364 0-2.816-.308-3.74-.858l.594-2.046c.682.396 1.826.814 3.124.814 1.76 0 3.08-.924 3.08-3.234v-.924h-.044c-.616.946-1.694 1.584-3.124 1.584-2.662 0-4.554-2.2-4.554-5.236 0-3.52 2.288-5.654 4.862-5.654 1.65 0 2.596.792 3.102 1.672h.044l.11-1.43h2.354c-.044.726-.088 1.606-.088 3.08zm-2.706 2.948v-1.738c0-.264-.022-.506-.088-.726-.286-.99-1.056-1.738-2.2-1.738-1.518 0-2.64 1.32-2.64 3.498 0 1.826.924 3.3 2.618 3.3 1.012 0 1.892-.66 2.2-1.65.088-.264.11-.638.11-.946zm5.622 4.686v-7.26c0-1.452-.022-2.508-.088-3.454h2.332l.11 2.024h.066c.528-1.496 1.782-2.266 2.948-2.266.264 0 .418.022.638.066v2.53c-.242-.044-.484-.066-.814-.066-1.276 0-2.178.814-2.42 2.046-.044.242-.066.528-.066.814v5.566zm16.05-6.424v3.85c0 .968.044 1.914.176 2.574h-2.442l-.198-1.188h-.066c-.638.836-1.76 1.43-3.168 1.43-2.156 0-3.366-1.562-3.366-3.19 0-2.684 2.398-4.07 6.358-4.048v-.176c0-.704-.286-1.87-2.178-1.87-1.056 0-2.156.33-2.882.792l-.528-1.76c.792-.484 2.178-.946 3.872-.946 3.432 0 4.422 2.178 4.422 4.532zm-2.64 2.662v-1.474c-1.914-.022-3.74.374-3.74 2.002 0 1.056.682 1.54 1.54 1.54 1.1 0 1.87-.704 2.134-1.474.066-.198.066-.396.066-.594zm5.6 3.762v-7.524c0-1.232-.044-2.266-.088-3.19h2.31l.132 1.584h.066c.506-.836 1.474-1.826 3.3-1.826 1.408 0 2.508.792 2.97 1.98h.044c.374-.594.814-1.034 1.298-1.342.616-.418 1.298-.638 2.2-.638 1.76 0 3.564 1.21 3.564 4.642v6.314h-2.64v-5.918c0-1.782-.616-2.838-1.914-2.838-.924 0-1.606.66-1.892 1.43-.088.242-.132.594-.132.902v6.424h-2.64v-6.204c0-1.496-.594-2.552-1.848-2.552-1.012 0-1.694.792-1.958 1.518-.088.286-.132.594-.132.902v6.336z" fill="var(--tme-logo-color)" fill-rule="nonzero"></path>
# </g>
# </svg>
# </a>
# <a class="tgme_head_right_btn" href="//telegram.org/dl?tme=5042628acaade21c5f_11790563518433198489">
#             Download
#           </a>
# </div>
# </div>
# <div class="tgme_body_wrap">
# <div class="tgme_page tgme_page_post">
# <div class="tgme_page_widget_wrap" id="widget">
# <div class="tgme_page_widget">
# <script data-mode="tme" data-telegram-post="tikvahethiopia/86164" data-width="100%" src="https://telegram.org/js/telegram-widget.js?22"></script>
# </div>
# </div>
# </div>
# <div class="tgme_page_widget_actions_wrap" id="widget_actions_wrap">
# <div class="tgme_page_widget_actions" id="widget_actions">
# <div class="tgme_page_widget_actions_cont">
# <div class="tgme_page_widget_action_right">
# <div class="tgme_page_context_btn"><a class="tgme_action_button_new" href="/s/tikvahethiopia/86164"><svg class="tgme_action_button_icon web_icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g class="icon_body" fill="none" stroke-width="2"><g><path d="M12 3c-2.386 0-4.677.949-6.364 2.636C3.949 7.323 3 9.614 3 12c0 2.386.949 4.677 2.636 6.364C7.323 20.051 9.614 21 12 21c2.386 0 4.677-.949 6.364-2.636C20.051 16.677 21 14.386 21 12c0-2.386-.949-4.677-2.636-6.364C16.677 3.949 14.386 3 12 3zM20.5 15h-17m17-6h-17"></path><path d="M12 21c-4.971 0-9-4.029-9-9s4.029-9 9-9" stroke-linecap="round"></path><path d="M12 21c-1-.5-3.5-4.029-3.5-9S11 3.5 12 3M12 21c1-.5 3.5-4.029 3.5-9S13 3.5 12 3" stroke-linecap="round"></path></g><g><path d="M36 3c-2.386 0-4.677.949-6.364 2.636C27.949 7.323 27 9.614 27 12c0 2.386.949 4.677 2.636 6.364C31.323 20.051 33.614 21 36 21c2.386 0 4.677-.949 6.364-2.636C44.051 16.677 45 14.386 45 12c0-2.386-.949-4.677-2.636-6.364C40.677 3.949 38.386 3 36 3zM44.5 15h-17m17-6h-17"></path><path d="M36 21c-4.942-.004-8.96-4.029-8.96-9S31.058 3.004 36 3" stroke-linecap="round"></path><path d="M36 21c-.986-.5-3.45-4.029-3.45-9S35.014 3.5 36 3M36 21c1.029-.496 3.54-4.029 3.54-9S37.029 3.496 36 3" stroke-linecap="round"></path></g><g><path d="M60 3c-2.386 0-4.677.949-6.364 2.636C51.949 7.323 51 9.614 51 12c0 2.386.949 4.677 2.636 6.364C55.323 20.051 57.614 21 60 21c2.386 0 4.677-.949 6.364-2.636C68.051 16.677 69 14.386 69 12c0-2.386-.949-4.677-2.636-6.364C64.677 3.949 62.386 3 60 3zM68.5 15h-17m17-6h-17"></path><path d="M60 21c-4.841-.016-8.82-4.029-8.82-9S55.159 3.016 60 3" stroke-linecap="round"></path><path d="M60 21c-.934-.5-3.27-4.029-3.27-9S59.066 3.5 60 3M60 21c1.13-.484 3.68-4.029 3.68-9S61.13 3.484 60 3" stroke-linecap="round"></path></g><g><path d="M84 3c-2.386 0-4.677.949-6.364 2.636C75.949 7.323 75 9.614 75 12c0 2.386.949 4.677 2.636 6.364C79.323 20.051 81.614 21 84 21c2.386 0 4.677-.949 6.364-2.636C92.051 16.677 93 14.386 93 12c0-2.386-.949-4.677-2.636-6.364C88.677 3.949 86.386 3 84 3zM92.5 15h-17m17-6h-17"></path><path d="M84 21c-4.633-.043-8.532-4.029-8.532-9S79.367 3.043 84 3" stroke-linecap="round"></path><path d="M84 21c-.83-.5-2.904-4.029-2.904-9S83.17 3.5 84 3M84 21c1.338-.457 3.968-4.029 3.968-9S85.338 3.457 84 3" stroke-linecap="round"></path></g><g><path d="M108 3c-2.386 0-4.677.949-6.364 2.636C99.949 7.323 99 9.614 99 12c0 2.386.949 4.677 2.636 6.364C103.323 20.051 105.614 21 108 21c2.386 0 4.677-.949 6.364-2.636C116.051 16.677 117 14.386 117 12c0-2.386-.949-4.677-2.636-6.364C112.677 3.949 110.386 3 108 3zM116.5 15h-17m17-6h-17"></path><path d="M108 21c-4.275-.088-8.037-4.029-8.037-9s3.762-8.912 8.037-9" stroke-linecap="round"></path><path d="M108 21c-.65-.5-2.274-4.029-2.274-9S107.35 3.5 108 3M108 21c1.696-.412 4.463-4.029 4.463-9S109.696 3.412 108 3" stroke-linecap="round"></path></g><g><path d="M132 3c-2.386 0-4.677.949-6.364 2.636C123.949 7.323 123 9.614 123 12c0 2.386.949 4.677 2.636 6.364C127.323 20.051 129.614 21 132 21c2.386 0 4.677-.949 6.364-2.636C140.051 16.677 141 14.386 141 12c0-2.386-.949-4.677-2.636-6.364C136.677 3.949 134.386 3 132 3zM140.5 15h-17m17-6h-17"></path><path d="M132 21c-3.751-.154-7.311-4.029-7.311-9s3.56-8.846 7.311-9" stroke-linecap="round"></path><path d="M132 21c-.386-.5-1.35-4.029-1.35-9s.964-8.5 1.35-9M132 21c2.22-.346 5.189-4.029 5.189-9S134.22 3.346 132 3" stroke-linecap="round"></path></g><g><path d="M156 3c-2.386 0-4.677.949-6.364 2.636C147.949 7.323 147 9.614 147 12c0 2.386.949 4.677 2.636 6.364C151.323 20.051 153.614 21 156 21c2.386 0 4.677-.949 6.364-2.636C164.051 16.677 165 14.386 165 12c0-2.386-.949-4.677-2.636-6.364C160.677 3.949 158.386 3 156 3zM164.5 15h-17m17-6h-17"></path><path d="M156 21c-3.155-.229-6.485-4.029-6.485-9s3.33-8.771 6.485-9" stroke-linecap="round"></path><path d="M156 21c-.085-.5-.299-4.029-.299-9s.214-8.5.299-9M156 21c2.816-.271 6.015-4.029 6.015-9S158.816 3.271 156 3" stroke-linecap="round"></path></g><g ...
# </div>
# <div class="tgme_page_widget_action_left">
# <div class="tgme_page_embed_btn">
# <a class="tgme_action_button_new" onclick="return toggleEmbed();"><svg class="tgme_action_button_icon embed_icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path class="icon_body" d="M8 16.5L3.5 12 8 7.5m8 9l4.5-4.5L16 7.5M31.83 16.5l-4.5-4.5 4.5-4.5m8.34 9l4.5-4.5-4.5-4.5M55.085 16.5l-4.5-4.5 4.5-4.5m9.83 9l4.5-4.5-4.5-4.5M78.449 16.5l-4.5-4.5 4.5-4.5m11.102 9l4.5-4.5-4.5-4.5M102.158 16.5l-4.5-4.5 4.5-4.5m11.684 9l4.5-4.5-4.5-4.5M126.033 16.5l-4.5-4.5 4.5-4.5m11.934 9l4.5-4.5-4.5-4.5M150 16.5l-4.5-4.5 4.5-4.5m12 9l4.5-4.5-4.5-4.5M174.098 16.5l-4.5-4.5 4.5-4.5m11.804 9l4.5-4.5-4.5-4.5M198.526 16.5l-4.5-4.5 4.5-4.5m10.948 9l4.5-4.5-4.5-4.5M223.372 16.5l-4.5-4.5 4.5-4.5m9.256 9l4.5-4.5-4.5-4.5M248.086 16.5l-4.5-4.5 4.5-4.5m7.828 9l4.5-4.5-4.5-4.5M272.511 16.5l-4.5-4.5 4.5-4.5m6.978 9l4.5-4.5-4.5-4.5M296.762 16.5l-4.5-4.5 4.5-4.5m6.476 9l4.5-4.5-4.5-4.5M320.906 16.5l-4.5-4.5 4.5-4.5m6.188 9l4.5-4.5-4.5-4.5M344.979 16.5l-4.5-4.5 4.5-4.5m6.042 9l4.5-4.5-4.5-4.5M369 16.5l-4.5-4.5 4.5-4.5m6 9l4.5-4.5-4.5-4.5M392.989 16.5l-4.5-4.5 4.5-4.5m6.022 9l4.5-4.5-4.5-4.5M416.95 16.5l-4.5-4.5 4.5-4.5m6.1 9l4.5-4.5-4.5-4.5M440.866 16.5l-4.5-4.5 4.5-4.5m6.268 9l4.5-4.5-4.5-4.5M464.722 16.5l-4.5-4.5 4.5-4.5m6.556 9l4.5-4.5-4.5-4.5M488.543 16.5l-4.5-4.5 4.5-4.5m6.914 9l4.5-4.5-4.5-4.5M512.386 16.5l-4.5-4.5 4.5-4.5m7.228 9l4.5-4.5-4.5-4.5M536.27 16.5l-4.5-4.5 4.5-4.5m7.46 9l4.5-4.5-4.5-4.5M560.186 16.5l-4.5-4.5 4.5-4.5m7.628 9l4.5-4.5-4.5-4.5M584.124 16.5l-4.5-4.5 4.5-4.5m7.752 9l4.5-4.5-4.5-4.5M608.079 16.5l-4.5-4.5 4.5-4.5m7.842 9l4.5-4.5-4.5-4.5M632.047 16.5l-4.5-4.5 4.5-4.5m7.906 9l4.5-4.5-4.5-4.5M656.025 16.5l-4.5-4.5 4.5-4.5m7.95 9l4.5-4.5-4.5-4.5M680.01 16.5l-4.5-4.5 4.5-4.5m7.98 9l4.5-4.5-4.5-4.5M704.002 16.5l-4.5-4.5 4.5-4.5m7.996 9l4.5-4.5-4.5-4.5M728 16.5l-4.5-4.5 4.5-4.5m8 9l4.5-4.5-4.5-4.5" fill="none" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg><span class="tgme_action_button_label">Embed</span></a>
# </div>
# </div>
# <div class="tgme_page_widget_action">
# <a class="tgme_action_button_new shine" href="tg://resolve?domain=tikvahethiopia&amp;post=86164">View In Channel</a>
# </div>
# <div class="tgme_page_embed_action">
# <textarea class="tgme_page_embed_code" id="embed_code_field" readonly="" rows="3">&lt;script async src="https://telegram.org/js/telegram-widget.js?22" data-telegram-post="tikvahethiopia/86164" data-width="100%"&gt;&lt;/script&gt;</textarea>
# <div class="tgme_page_copy_action">
# <a class="tgme_action_button_new" id="widget_copy" onclick="return copyEmbedCode(this);"><svg class="tgme_action_button_icon copy_icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g class="icon_body" fill="none" stroke-width="2"><g><path d="M8.5 6h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707V7c0-.265.105-.52.293-.707C7.98 6.105 8.235 6 8.5 6"></path><path d="M15.5 2h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M32.33 5.83h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M39.67 2.17h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M55.585 5.085h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M64.415 2.915h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M78.949 4.449h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M89.051 3.551h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M102.658 4.158h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M113.342 3.842h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M126.533 4.033h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M137.467 3.967h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M150.5 4h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707V5c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M161.5 4h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M174.598 4.098h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M185.402 3.902h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M199.026 4.526h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M208.974 3.474h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M223.872 5.372h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M232.128 2.628h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M248.586 6.086h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M255.414 1.914h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M273.011 6.511h11c.265 0 .5 ...
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tgme_page_widget_actions_helper" id="widget_actions_helper"></div>
# </div>
# </div>
# <div id="tgme_frame_cont"></div>
# <script src="//telegram.org/js/tgwallpaper.min.js?3"></script>
# <script type="text/javascript">
#
# var protoUrl = "tg:\/\/resolve?domain=tikvahethiopia&post=86164";
# if (false) {
#   var iframeContEl = document.getElementById('tgme_frame_cont') || document.body;
#   var iframeEl = document.createElement('iframe');
#   iframeContEl.appendChild(iframeEl);
#   var pageHidden = false;
#   window.addEventListener('pagehide', function () {
#     pageHidden = true;
#   }, false);
#   window.addEventListener('blur', function () {
#     pageHidden = true;
#   }, false);
#   if (iframeEl !== null) {
#     iframeEl.src = protoUrl;
#   }
#   !false && setTimeout(function() {
#     if (!pageHidden) {
#       window.location = protoUrl;
#     }
#   }, 2000);
# }
# else if (protoUrl) {
#   setTimeout(function() {
#     window.location = protoUrl;
#   }, 100);
# }
#
# var tme_bg = document.getElementById('tgme_background');
# if (tme_bg) {
#   TWallpaper.init(tme_bg);
#   TWallpaper.animate(true);
#   window.onfocus = function(){ TWallpaper.update(); };
# }
# document.body.classList.remove('no_transition');
#
# function toggleTheme(dark) {
#   document.documentElement.classList.toggle('theme_dark', dark);
#   window.Telegram && Telegram.setWidgetOptions({dark: dark});
# }
# if (window.matchMedia) {
#   var darkMedia = window.matchMedia('(prefers-color-scheme: dark)');
#   toggleTheme(darkMedia.matches);
#   darkMedia.addListener(function(e) {
#     toggleTheme(e.matches);
#   });
# }
#
#     function toggleEmbed() {
#   var widget_actions = document.getElementById('widget_actions');
#   if (widget_actions.classList.contains('embed_opened')) {
#     widget_actions.classList.remove('embed_opened');
#     var widget_copy = document.getElementById('widget_copy');
#     if (widget_copy.classList.contains('pressed')) {
#       widget_copy.classList.remove('pressed');
#     }
#   } else {
#     widget_actions.classList.add('embed_opened');
#     if (!document.body.classList.contains('fixed_actions')) {
#       window.scrollTo(0, document.body.offsetHeight);
#     }
#     selectEmbedCode();
#   }
#   checkActionsPosition();
#   return false;
# }
# function selectEmbedCode() {
#   var field = document.getElementById('embed_code_field');
#   field.focus();
#   field.setSelectionRange(0, field.value.length);
# }
# function copyEmbedCode(btn) {
#   if (btn.classList.contains('pressed')) {
#     btn.classList.remove('pressed');
#     btn.offsetTop + 1;
#   }
#   btn.classList.add('pressed');
#   selectEmbedCode();
#   document.execCommand('copy');
#   return false;
# }
# function pauseWallpaper(el) {
#   var animEnd = function() {
#     el.removeEventListener('transitionend', animEnd);
#     TWallpaper.animate(true);
#   }
#   TWallpaper.animate(false);
#   el.addEventListener('transitionend', animEnd);
# }
# function checkActionsPosition() {
#   var widget = document.getElementById('widget');
#   var widget_actions_wrap = document.getElementById('widget_actions_wrap');
#   var widget_actions = document.getElementById('widget_actions');
#   var widget_rect = widget.getBoundingClientRect();
#   var actions_bottom = widget_rect.bottom + widget_actions_wrap.offsetHeight;
#   var client_bottom = window.innerHeight || html.clientHeight;
#   var body_classlist = document.body.classList;
#   if (actions_bottom > client_bottom) {
#     if (!body_classlist.contains('fixed_actions')) {
#       widget.style.marginBottom = widget_actions_wrap.offsetHeight + 'px';
#       pauseWallpaper(widget_actions);
#       body_classlist.add('fixed_actions');
#     }
#   } else {
#     if (body_classlist.contains('fixed_actions')) {
#       widget.style.marginBottom = '';
#       pauseWallpaper(widget_actions);
#       body_classlist.remove('fixed_actions');
#     }
#   }
# }
# function postMessageHandler(event) {
#   try { var data = JSON.parse(event.data); }
#   catch(e) { var data = {}; }
#   if (data.event == 'resize') {
#     setTimeout(checkActionsPosition, 50);
#   }
# }
# if (!CSS || !CSS.supports || !CSS.supports('position', 'sticky') || !IntersectionObserver) {
#   window.addEventListener('resize', checkActionsPosition);
#   window.addEventListener('scroll', checkActionsPosition);
#   window.addEventListener('message', postMessageHandler);
# } else {
#   document.body.classList.add('sticky_actions');
#   var observer = new IntersectionObserver(function(records, observer) {
#     for (var i = 0; i < records.length; i++) {
#       var record = records[i];
#       var widget_actions_wrap = document.getElementById('widget_actions_wrap');
#       var widget_actions = document.getElementById('widget_actions');
#       if (widget_actions_wrap) {
#         pauseWallpaper(widget_actions);
#         widget_actions_wrap.classList.toggle('stuck', !record.isIntersecting);
#       }
#     }
#   }, {threshold: [0], root: document});
#   observer.observe(document.getElementById('widget_actions_helper'));
# }
#
#     </script>
# </body>
# </html>
# <!-- page generated in 9.86ms -->

# %%
results = soup.find_all('div', class_='tgme_widget_message_footer')

# %%
len(results)
# Out:
# 0

# %%
results[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 results[0]
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

post = 'https://t.me/tikvahethiopia/86164'

response = requests.get(post)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the iframe element
iframe = soup.find('iframe', id='telegram-post-tikvahethiopia-86164')

# Get the iframe source URL
iframe_src = iframe['src']

# Make a new request to the iframe source
iframe_response = requests.get(iframe_src)
iframe_soup = BeautifulSoup(iframe_response.content, 'html.parser')

# Now you can search for the desired elements within iframe_soup
info_div = iframe_soup.find('div', class_='tgme_widget_message_info js-message_info')

# Extract views
views_span = info_div.find('span', class_='tgme_widget_message_views')
views = views_span.text.strip() if views_span else None

# Extract date and time
date_element = info_div.find('a', class_='tgme_widget_message_date')
datetime_element = date_element.find('time', class_='datetime') if date_element else None
date_time = datetime_element['datetime'] if datetime_element else None

print(f"Views: {views}")
print(f"Date and Time: {date_time}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 13
#      10 iframe = soup.find('iframe', id='telegram-post-tikvahethiopia-86164')
#      12 # Get the iframe source URL
# ---> 13 iframe_src = iframe['src']
#      15 # Make a new request to the iframe source
#      16 iframe_response = requests.get(iframe_src)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

post = 'https://t.me/tikvahethiopia/86164'

# Initialize a browser driver (e.g., Chrome)
driver = webdriver.Chrome()

# Load the Telegram post URL
driver.get(post)

# Wait for the iframe to load (adjust the wait time if needed)
driver.implicitly_wait(10)  # Wait up to 10 seconds

# Get the page source after JavaScript execution
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# ... rest of the code to find elements within the iframe ...

# Close the browser driver
driver.quit()

# %%
soup
# Out:
# <html class="theme_dark"><head>
# <meta charset="utf-8"/>
# <title>Telegram: Contact @tikvahethiopia</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script>try{if(window.parent!=null&&window!=window.parent){window.parent.postMessage(JSON.stringify({eventType:'web_app_open_tg_link',eventData:{path_full:"\/tikvahethiopia\/86164"}}),'https://web.telegram.org');}}catch(e){}</script>
# <meta content="TIKVAH-ETHIOPIA" property="og:title"/>
# <meta content="https://cdn4.cdn-telegram.org/file/jEUJN2otuVe2oOJdP-aj8ipSQFkBZcZHmldZT7fvC-zsA2V0loMJGmF8SE78xx-KQJytPp4Q3TtuP6kn-Dv-56B4ZkvXm2g4Kj5IZyTspKM5GdPr0JnhA9c0ideJ_B_ZfyqVazIvlf7Xc5Cw-O1l12XPL6o3edFXXX_5GE-vT9PzapHQH1MDxSuvrKFeg_clQ3WHlQMZ6wJVZRpl1FQ7q8dgnamTTemni1rOM6g0ZGrhLeu69eKWneNVAd8_n2dRh1lFoS2fetZpcnlEg3OpFu_ZiBBL2c-cLv9LPDUQdtSs3gDv1v9gHz34tox_x0eUkxIvlnercp1SBSZqJC_MoA.jpg" property="og:image"/>
# <meta content="Telegram" property="og:site_name"/>
# <meta content="መተግበሪያዎን ሲቢኢ ብር ላይ ያስቀምጡ
# በቀላሉ በርካታ ደንበኞች ዘንድ  ይድረሱ!
#
# #CBE #cbebirr #apps #digitalbanking
# *************
# የሲቢኢ ብር መተግበሪያ ማስፈንጠሪያ፡
#
# • ለአንድሮይድ ስልኮች፡ https://play.google.com/store/apps/details?id=prod.cbe.birr
# • ለአፕል ስልኮች፡ https://apps.apple.com/us/app/cbebirr/id1600841787" property="og:description"/>
# <meta content="TIKVAH-ETHIOPIA" property="twitter:title"/>
# <meta content="https://cdn4.cdn-telegram.org/file/jEUJN2otuVe2oOJdP-aj8ipSQFkBZcZHmldZT7fvC-zsA2V0loMJGmF8SE78xx-KQJytPp4Q3TtuP6kn-Dv-56B4ZkvXm2g4Kj5IZyTspKM5GdPr0JnhA9c0ideJ_B_ZfyqVazIvlf7Xc5Cw-O1l12XPL6o3edFXXX_5GE-vT9PzapHQH1MDxSuvrKFeg_clQ3WHlQMZ6wJVZRpl1FQ7q8dgnamTTemni1rOM6g0ZGrhLeu69eKWneNVAd8_n2dRh1lFoS2fetZpcnlEg3OpFu_ZiBBL2c-cLv9LPDUQdtSs3gDv1v9gHz34tox_x0eUkxIvlnercp1SBSZqJC_MoA.jpg" property="twitter:image"/>
# <meta content="@Telegram" property="twitter:site"/>
# <meta content="686449807" property="al:ios:app_store_id"/>
# <meta content="Telegram Messenger" property="al:ios:app_name"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" property="al:ios:url"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" property="al:android:url"/>
# <meta content="Telegram" property="al:android:app_name"/>
# <meta content="org.telegram.messenger" property="al:android:package"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@Telegram" name="twitter:site"/>
# <meta content="መተግበሪያዎን ሲቢኢ ብር ላይ ያስቀምጡ
# በቀላሉ በርካታ ደንበኞች ዘንድ  ይድረሱ!
#
# #CBE #cbebirr #apps #digitalbanking
# *************
# የሲቢኢ ብር መተግበሪያ ማስፈንጠሪያ፡
#
# • ለአንድሮይድ ስልኮች፡ https://play.google.com/store/apps/details?id=prod.cbe.birr
# • ለአፕል ስልኮች፡ https://apps.apple.com/us/app/cbebirr/id1600841787
# " name="twitter:description"/>
# <meta content="Telegram Messenger" name="twitter:app:name:iphone"/>
# <meta content="686449807" name="twitter:app:id:iphone"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" name="twitter:app:url:iphone"/>
# <meta content="Telegram Messenger" name="twitter:app:name:ipad"/>
# <meta content="686449807" name="twitter:app:id:ipad"/>
# <meta content="tg://resolve?domain=tikvahethiopia&amp;post=86164" name="twitter:app:url:ipad"/>
# <meta content="Telegram" name="twitter:app:name:googleplay"/>
# <meta content="org.telegram.messenger" name="twitter:app:id:googleplay"/>
# <meta content="https://t.me/tikvahethiopia/86164" name="twitter:app:url:googleplay"/>
# <meta content="app-id=686449807, app-argument: tg://resolve?domain=tikvahethiopia&amp;post=86164" name="apple-itunes-app"/>
# <script>window.matchMedia&&window.matchMedia('(prefers-color-scheme: dark)').matches&&document.documentElement&&document.documentElement.classList&&document.documentElement.classList.add('theme_dark');</script>
# <link href="//telegram.org/img/website_icon.svg?4" rel="icon" type="image/svg+xml"/>
# <link href="//telegram.org/img/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="//telegram.org/img/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//telegram.org/img/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//telegram.org/img/favicon.ico" rel="alternate icon" type="image/x-icon"/>
# <link href="//telegram.org/css/font-roboto.css?1" rel="stylesheet" type="text/css"/>
# <!--link href="/css/myriad.css" rel="stylesheet"-->
# <link href="//telegram.org/css/bootstrap.min.css?3" rel="stylesheet"/>
# <link href="//telegram.org/css/telegram.css?237" media="screen" rel="stylesheet"/>
# </head>
# <body class="sticky_actions">
# <div class="tgme_background_wrap">
# <canvas class="tgme_background default" data-colors="dbddbb,6ba587,d5d88d,88b884" height="50" id="tgme_background" width="50"></canvas>
# <div class="tgme_background_pattern default"></div>
# </div>
# <div class="tgme_page_wrap">
# <div class="tgme_head_wrap">
# <div class="tgme_head">
# <a class="tgme_head_brand" href="//telegram.org/">
# <svg class="tgme_logo" height="34" viewbox="0 0 133 34" width="133" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <circle cx="17" cy="17" fill="var(--accent-btn-color)" r="17"></circle><path d="m7.06510669 16.9258959c5.22739451-2.1065178 8.71314291-3.4952633 10.45724521-4.1662364 4.9797665-1.9157646 6.0145193-2.2485535 6.6889567-2.2595423.1483363-.0024169.480005.0315855.6948461.192827.1814076.1361492.23132.3200675.2552048.4491519.0238847.1290844.0536269.4231419.0299841.65291-.2698553 2.6225356-1.4375148 8.986738-2.0315537 11.9240228-.2513602 1.2428753-.7499132 1.5088847-1.2290685 1.5496672-1.0413153.0886298-1.8284257-.4857912-2.8369905-1.0972863-1.5782048-.9568691-2.5327083-1.3984317-4.0646293-2.3321592-1.7703998-1.0790837-.212559-1.583655.7963867-2.5529189.2640459-.2536609 4.7753906-4.3097041 4.755976-4.431706-.0070494-.0442984-.1409018-.481649-.2457499-.5678447-.104848-.0861957-.2595946-.0567202-.3712641-.033278-.1582881.0332286-2.6794907 1.5745492-7.5636077 4.6239616-.715635.4545193-1.3638349.6759763-1.9445998.6643712-.64024672-.0127938-1.87182452-.334829-2.78737602-.6100966-1.12296117-.3376271-1.53748501-.4966332-1.45976769-1.0700283.04048-.2986597.32581586-.610598.8560076-.935815z" fill="#fff"></path><path d="m49.4 24v-12.562h-4.224v-2.266h11.198v2.266h-4.268v12.562zm16.094-4.598h-7.172c.066 1.936 1.562 2.772 3.3 2.772 1.254 0 2.134-.198 2.97-.484l.396 1.848c-.924.396-2.2.682-3.74.682-3.476 0-5.522-2.134-5.522-5.412 0-2.97 1.804-5.764 5.236-5.764 3.476 0 4.62 2.86 4.62 5.214 0 .506-.044.902-.088 1.144zm-7.172-1.892h4.708c.022-.99-.418-2.618-2.222-2.618-1.672 0-2.376 1.518-2.486 2.618zm9.538 6.49v-15.62h2.706v15.62zm14.84-4.598h-7.172c.066 1.936 1.562 2.772 3.3 2.772 1.254 0 2.134-.198 2.97-.484l.396 1.848c-.924.396-2.2.682-3.74.682-3.476 0-5.522-2.134-5.522-5.412 0-2.97 1.804-5.764 5.236-5.764 3.476 0 4.62 2.86 4.62 5.214 0 .506-.044.902-.088 1.144zm-7.172-1.892h4.708c.022-.99-.418-2.618-2.222-2.618-1.672 0-2.376 1.518-2.486 2.618zm19.24-1.144v6.072c0 2.244-.462 3.85-1.584 4.862-1.1.99-2.662 1.298-4.136 1.298-1.364 0-2.816-.308-3.74-.858l.594-2.046c.682.396 1.826.814 3.124.814 1.76 0 3.08-.924 3.08-3.234v-.924h-.044c-.616.946-1.694 1.584-3.124 1.584-2.662 0-4.554-2.2-4.554-5.236 0-3.52 2.288-5.654 4.862-5.654 1.65 0 2.596.792 3.102 1.672h.044l.11-1.43h2.354c-.044.726-.088 1.606-.088 3.08zm-2.706 2.948v-1.738c0-.264-.022-.506-.088-.726-.286-.99-1.056-1.738-2.2-1.738-1.518 0-2.64 1.32-2.64 3.498 0 1.826.924 3.3 2.618 3.3 1.012 0 1.892-.66 2.2-1.65.088-.264.11-.638.11-.946zm5.622 4.686v-7.26c0-1.452-.022-2.508-.088-3.454h2.332l.11 2.024h.066c.528-1.496 1.782-2.266 2.948-2.266.264 0 .418.022.638.066v2.53c-.242-.044-.484-.066-.814-.066-1.276 0-2.178.814-2.42 2.046-.044.242-.066.528-.066.814v5.566zm16.05-6.424v3.85c0 .968.044 1.914.176 2.574h-2.442l-.198-1.188h-.066c-.638.836-1.76 1.43-3.168 1.43-2.156 0-3.366-1.562-3.366-3.19 0-2.684 2.398-4.07 6.358-4.048v-.176c0-.704-.286-1.87-2.178-1.87-1.056 0-2.156.33-2.882.792l-.528-1.76c.792-.484 2.178-.946 3.872-.946 3.432 0 4.422 2.178 4.422 4.532zm-2.64 2.662v-1.474c-1.914-.022-3.74.374-3.74 2.002 0 1.056.682 1.54 1.54 1.54 1.1 0 1.87-.704 2.134-1.474.066-.198.066-.396.066-.594zm5.6 3.762v-7.524c0-1.232-.044-2.266-.088-3.19h2.31l.132 1.584h.066c.506-.836 1.474-1.826 3.3-1.826 1.408 0 2.508.792 2.97 1.98h.044c.374-.594.814-1.034 1.298-1.342.616-.418 1.298-.638 2.2-.638 1.76 0 3.564 1.21 3.564 4.642v6.314h-2.64v-5.918c0-1.782-.616-2.838-1.914-2.838-.924 0-1.606.66-1.892 1.43-.088.242-.132.594-.132.902v6.424h-2.64v-6.204c0-1.496-.594-2.552-1.848-2.552-1.012 0-1.694.792-1.958 1.518-.088.286-.132.594-.132.902v6.336z" fill="var(--tme-logo-color)" fill-rule="nonzero"></path>
# </g>
# </svg>
# </a>
# <a class="tgme_head_right_btn" href="//telegram.org/dl?tme=39895390c558dfd48c_17737584894348469706">
#             Download
#           </a>
# </div>
# </div>
# <div class="tgme_body_wrap">
# <div class="tgme_page tgme_page_post">
# <div class="tgme_page_widget_wrap" id="widget">
# <div class="tgme_page_widget">
# <iframe frameborder="0" height="" id="telegram-post-tikvahethiopia-86164" scrolling="no" src="https://t.me/tikvahethiopia/86164?embed=1&amp;mode=tme" style="overflow: hidden; color-scheme: light dark; border: none; min-width: 320px; height: 860px;" width="100%"></iframe><script data-mode="tme" data-telegram-post="tikvahethiopia/86164" data-width="100%" src="https://telegram.org/js/telegram-widget.js?22"></script>
# </div>
# </div>
# </div>
# <div class="tgme_page_widget_actions_wrap stuck" id="widget_actions_wrap">
# <div class="tgme_page_widget_actions" id="widget_actions">
# <div class="tgme_page_widget_actions_cont">
# <div class="tgme_page_widget_action_right">
# <div class="tgme_page_context_btn"><a class="tgme_action_button_new" href="/s/tikvahethiopia/86164"><svg class="tgme_action_button_icon web_icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g class="icon_body" fill="none" stroke-width="2"><g><path d="M12 3c-2.386 0-4.677.949-6.364 2.636C3.949 7.323 3 9.614 3 12c0 2.386.949 4.677 2.636 6.364C7.323 20.051 9.614 21 12 21c2.386 0 4.677-.949 6.364-2.636C20.051 16.677 21 14.386 21 12c0-2.386-.949-4.677-2.636-6.364C16.677 3.949 14.386 3 12 3zM20.5 15h-17m17-6h-17"></path><path d="M12 21c-4.971 0-9-4.029-9-9s4.029-9 9-9" stroke-linecap="round"></path><path d="M12 21c-1-.5-3.5-4.029-3.5-9S11 3.5 12 3M12 21c1-.5 3.5-4.029 3.5-9S13 3.5 12 3" stroke-linecap="round"></path></g><g><path d="M36 3c-2.386 0-4.677.949-6.364 2.636C27.949 7.323 27 9.614 27 12c0 2.386.949 4.677 2.636 6.364C31.323 20.051 33.614 21 36 21c2.386 0 4.677-.949 6.364-2.636C44.051 16.677 45 14.386 45 12c0-2.386-.949-4.677-2.636-6.364C40.677 3.949 38.386 3 36 3zM44.5 15h-17m17-6h-17"></path><path d="M36 21c-4.942-.004-8.96-4.029-8.96-9S31.058 3.004 36 3" stroke-linecap="round"></path><path d="M36 21c-.986-.5-3.45-4.029-3.45-9S35.014 3.5 36 3M36 21c1.029-.496 3.54-4.029 3.54-9S37.029 3.496 36 3" stroke-linecap="round"></path></g><g><path d="M60 3c-2.386 0-4.677.949-6.364 2.636C51.949 7.323 51 9.614 51 12c0 2.386.949 4.677 2.636 6.364C55.323 20.051 57.614 21 60 21c2.386 0 4.677-.949 6.364-2.636C68.051 16.677 69 14.386 69 12c0-2.386-.949-4.677-2.636-6.364C64.677 3.949 62.386 3 60 3zM68.5 15h-17m17-6h-17"></path><path d="M60 21c-4.841-.016-8.82-4.029-8.82-9S55.159 3.016 60 3" stroke-linecap="round"></path><path d="M60 21c-.934-.5-3.27-4.029-3.27-9S59.066 3.5 60 3M60 21c1.13-.484 3.68-4.029 3.68-9S61.13 3.484 60 3" stroke-linecap="round"></path></g><g><path d="M84 3c-2.386 0-4.677.949-6.364 2.636C75.949 7.323 75 9.614 75 12c0 2.386.949 4.677 2.636 6.364C79.323 20.051 81.614 21 84 21c2.386 0 4.677-.949 6.364-2.636C92.051 16.677 93 14.386 93 12c0-2.386-.949-4.677-2.636-6.364C88.677 3.949 86.386 3 84 3zM92.5 15h-17m17-6h-17"></path><path d="M84 21c-4.633-.043-8.532-4.029-8.532-9S79.367 3.043 84 3" stroke-linecap="round"></path><path d="M84 21c-.83-.5-2.904-4.029-2.904-9S83.17 3.5 84 3M84 21c1.338-.457 3.968-4.029 3.968-9S85.338 3.457 84 3" stroke-linecap="round"></path></g><g><path d="M108 3c-2.386 0-4.677.949-6.364 2.636C99.949 7.323 99 9.614 99 12c0 2.386.949 4.677 2.636 6.364C103.323 20.051 105.614 21 108 21c2.386 0 4.677-.949 6.364-2.636C116.051 16.677 117 14.386 117 12c0-2.386-.949-4.677-2.636-6.364C112.677 3.949 110.386 3 108 3zM116.5 15h-17m17-6h-17"></path><path d="M108 21c-4.275-.088-8.037-4.029-8.037-9s3.762-8.912 8.037-9" stroke-linecap="round"></path><path d="M108 21c-.65-.5-2.274-4.029-2.274-9S107.35 3.5 108 3M108 21c1.696-.412 4.463-4.029 4.463-9S109.696 3.412 108 3" stroke-linecap="round"></path></g><g><path d="M132 3c-2.386 0-4.677.949-6.364 2.636C123.949 7.323 123 9.614 123 12c0 2.386.949 4.677 2.636 6.364C127.323 20.051 129.614 21 132 21c2.386 0 4.677-.949 6.364-2.636C140.051 16.677 141 14.386 141 12c0-2.386-.949-4.677-2.636-6.364C136.677 3.949 134.386 3 132 3zM140.5 15h-17m17-6h-17"></path><path d="M132 21c-3.751-.154-7.311-4.029-7.311-9s3.56-8.846 7.311-9" stroke-linecap="round"></path><path d="M132 21c-.386-.5-1.35-4.029-1.35-9s.964-8.5 1.35-9M132 21c2.22-.346 5.189-4.029 5.189-9S134.22 3.346 132 3" stroke-linecap="round"></path></g><g><path d="M156 3c-2.386 0-4.677.949-6.364 2.636C147.949 7.323 147 9.614 147 12c0 2.386.949 4.677 2.636 6.364C151.323 20.051 153.614 21 156 21c2.386 0 4.677-.949 6.364-2.636C164.051 16.677 165 14.386 165 12c0-2.386-.949-4.677-2.636-6.364C160.677 3.949 158.386 3 156 3zM164.5 15h-17m17-6h-17"></path><path d="M156 21c-3.155-.229-6.485-4.029-6.485-9s3.33-8.771 6.485-9" stroke-linecap="round"></path><path d="M156 21c-.085-.5-.299-4.029-.299-9s.214-8.5.299-9M156 21c2.816-.271 6.015-4.029 6.015-9S158.816 3.271 156 3" stroke-linecap="round"></path></g><g ...
# </div>
# <div class="tgme_page_widget_action_left">
# <div class="tgme_page_embed_btn">
# <a class="tgme_action_button_new" onclick="return toggleEmbed();"><svg class="tgme_action_button_icon embed_icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path class="icon_body" d="M8 16.5L3.5 12 8 7.5m8 9l4.5-4.5L16 7.5M31.83 16.5l-4.5-4.5 4.5-4.5m8.34 9l4.5-4.5-4.5-4.5M55.085 16.5l-4.5-4.5 4.5-4.5m9.83 9l4.5-4.5-4.5-4.5M78.449 16.5l-4.5-4.5 4.5-4.5m11.102 9l4.5-4.5-4.5-4.5M102.158 16.5l-4.5-4.5 4.5-4.5m11.684 9l4.5-4.5-4.5-4.5M126.033 16.5l-4.5-4.5 4.5-4.5m11.934 9l4.5-4.5-4.5-4.5M150 16.5l-4.5-4.5 4.5-4.5m12 9l4.5-4.5-4.5-4.5M174.098 16.5l-4.5-4.5 4.5-4.5m11.804 9l4.5-4.5-4.5-4.5M198.526 16.5l-4.5-4.5 4.5-4.5m10.948 9l4.5-4.5-4.5-4.5M223.372 16.5l-4.5-4.5 4.5-4.5m9.256 9l4.5-4.5-4.5-4.5M248.086 16.5l-4.5-4.5 4.5-4.5m7.828 9l4.5-4.5-4.5-4.5M272.511 16.5l-4.5-4.5 4.5-4.5m6.978 9l4.5-4.5-4.5-4.5M296.762 16.5l-4.5-4.5 4.5-4.5m6.476 9l4.5-4.5-4.5-4.5M320.906 16.5l-4.5-4.5 4.5-4.5m6.188 9l4.5-4.5-4.5-4.5M344.979 16.5l-4.5-4.5 4.5-4.5m6.042 9l4.5-4.5-4.5-4.5M369 16.5l-4.5-4.5 4.5-4.5m6 9l4.5-4.5-4.5-4.5M392.989 16.5l-4.5-4.5 4.5-4.5m6.022 9l4.5-4.5-4.5-4.5M416.95 16.5l-4.5-4.5 4.5-4.5m6.1 9l4.5-4.5-4.5-4.5M440.866 16.5l-4.5-4.5 4.5-4.5m6.268 9l4.5-4.5-4.5-4.5M464.722 16.5l-4.5-4.5 4.5-4.5m6.556 9l4.5-4.5-4.5-4.5M488.543 16.5l-4.5-4.5 4.5-4.5m6.914 9l4.5-4.5-4.5-4.5M512.386 16.5l-4.5-4.5 4.5-4.5m7.228 9l4.5-4.5-4.5-4.5M536.27 16.5l-4.5-4.5 4.5-4.5m7.46 9l4.5-4.5-4.5-4.5M560.186 16.5l-4.5-4.5 4.5-4.5m7.628 9l4.5-4.5-4.5-4.5M584.124 16.5l-4.5-4.5 4.5-4.5m7.752 9l4.5-4.5-4.5-4.5M608.079 16.5l-4.5-4.5 4.5-4.5m7.842 9l4.5-4.5-4.5-4.5M632.047 16.5l-4.5-4.5 4.5-4.5m7.906 9l4.5-4.5-4.5-4.5M656.025 16.5l-4.5-4.5 4.5-4.5m7.95 9l4.5-4.5-4.5-4.5M680.01 16.5l-4.5-4.5 4.5-4.5m7.98 9l4.5-4.5-4.5-4.5M704.002 16.5l-4.5-4.5 4.5-4.5m7.996 9l4.5-4.5-4.5-4.5M728 16.5l-4.5-4.5 4.5-4.5m8 9l4.5-4.5-4.5-4.5" fill="none" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg><span class="tgme_action_button_label">Embed</span></a>
# </div>
# </div>
# <div class="tgme_page_widget_action">
# <a class="tgme_action_button_new shine" href="tg://resolve?domain=tikvahethiopia&amp;post=86164">View In Channel</a>
# </div>
# <div class="tgme_page_embed_action">
# <textarea class="tgme_page_embed_code" id="embed_code_field" readonly="" rows="3">&lt;script async src="https://telegram.org/js/telegram-widget.js?22" data-telegram-post="tikvahethiopia/86164" data-width="100%"&gt;&lt;/script&gt;</textarea>
# <div class="tgme_page_copy_action">
# <a class="tgme_action_button_new" id="widget_copy" onclick="return copyEmbedCode(this);"><svg class="tgme_action_button_icon copy_icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g class="icon_body" fill="none" stroke-width="2"><g><path d="M8.5 6h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707V7c0-.265.105-.52.293-.707C7.98 6.105 8.235 6 8.5 6"></path><path d="M15.5 2h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M32.33 5.83h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M39.67 2.17h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M55.585 5.085h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M64.415 2.915h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M78.949 4.449h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M89.051 3.551h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M102.658 4.158h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M113.342 3.842h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M126.533 4.033h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M137.467 3.967h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M150.5 4h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707V5c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M161.5 4h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M174.598 4.098h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M185.402 3.902h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M199.026 4.526h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M208.974 3.474h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M223.872 5.372h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M232.128 2.628h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M248.586 6.086h11c.265 0 .52.105.707.293.188.187.293.442.293.707v14c0 .265-.105.52-.293.707-.187.188-.442.293-.707.293h-11c-.265 0-.52-.105-.707-.293-.188-.187-.293-.442-.293-.707v-14c0-.265.105-.52.293-.707.187-.188.442-.293.707-.293"></path><path d="M255.414 1.914h-11c-.552 0-1 .448-1 1v13" stroke-linecap="round"></path></g><g><path d="M273.011 6.511h11c.265 0 .5 ...
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tgme_page_widget_actions_helper" id="widget_actions_helper"></div>
# </div>
# </div>
# <div id="tgme_frame_cont"></div>
# <script src="//telegram.org/js/tgwallpaper.min.js?3"></script>
# <script type="text/javascript">
#
# var protoUrl = "tg:\/\/resolve?domain=tikvahethiopia&post=86164";
# if (false) {
#   var iframeContEl = document.getElementById('tgme_frame_cont') || document.body;
#   var iframeEl = document.createElement('iframe');
#   iframeContEl.appendChild(iframeEl);
#   var pageHidden = false;
#   window.addEventListener('pagehide', function () {
#     pageHidden = true;
#   }, false);
#   window.addEventListener('blur', function () {
#     pageHidden = true;
#   }, false);
#   if (iframeEl !== null) {
#     iframeEl.src = protoUrl;
#   }
#   !false && setTimeout(function() {
#     if (!pageHidden) {
#       window.location = protoUrl;
#     }
#   }, 2000);
# }
# else if (protoUrl) {
#   setTimeout(function() {
#     window.location = protoUrl;
#   }, 100);
# }
#
# var tme_bg = document.getElementById('tgme_background');
# if (tme_bg) {
#   TWallpaper.init(tme_bg);
#   TWallpaper.animate(true);
#   window.onfocus = function(){ TWallpaper.update(); };
# }
# document.body.classList.remove('no_transition');
#
# function toggleTheme(dark) {
#   document.documentElement.classList.toggle('theme_dark', dark);
#   window.Telegram && Telegram.setWidgetOptions({dark: dark});
# }
# if (window.matchMedia) {
#   var darkMedia = window.matchMedia('(prefers-color-scheme: dark)');
#   toggleTheme(darkMedia.matches);
#   darkMedia.addListener(function(e) {
#     toggleTheme(e.matches);
#   });
# }
#
#     function toggleEmbed() {
#   var widget_actions = document.getElementById('widget_actions');
#   if (widget_actions.classList.contains('embed_opened')) {
#     widget_actions.classList.remove('embed_opened');
#     var widget_copy = document.getElementById('widget_copy');
#     if (widget_copy.classList.contains('pressed')) {
#       widget_copy.classList.remove('pressed');
#     }
#   } else {
#     widget_actions.classList.add('embed_opened');
#     if (!document.body.classList.contains('fixed_actions')) {
#       window.scrollTo(0, document.body.offsetHeight);
#     }
#     selectEmbedCode();
#   }
#   checkActionsPosition();
#   return false;
# }
# function selectEmbedCode() {
#   var field = document.getElementById('embed_code_field');
#   field.focus();
#   field.setSelectionRange(0, field.value.length);
# }
# function copyEmbedCode(btn) {
#   if (btn.classList.contains('pressed')) {
#     btn.classList.remove('pressed');
#     btn.offsetTop + 1;
#   }
#   btn.classList.add('pressed');
#   selectEmbedCode();
#   document.execCommand('copy');
#   return false;
# }
# function pauseWallpaper(el) {
#   var animEnd = function() {
#     el.removeEventListener('transitionend', animEnd);
#     TWallpaper.animate(true);
#   }
#   TWallpaper.animate(false);
#   el.addEventListener('transitionend', animEnd);
# }
# function checkActionsPosition() {
#   var widget = document.getElementById('widget');
#   var widget_actions_wrap = document.getElementById('widget_actions_wrap');
#   var widget_actions = document.getElementById('widget_actions');
#   var widget_rect = widget.getBoundingClientRect();
#   var actions_bottom = widget_rect.bottom + widget_actions_wrap.offsetHeight;
#   var client_bottom = window.innerHeight || html.clientHeight;
#   var body_classlist = document.body.classList;
#   if (actions_bottom > client_bottom) {
#     if (!body_classlist.contains('fixed_actions')) {
#       widget.style.marginBottom = widget_actions_wrap.offsetHeight + 'px';
#       pauseWallpaper(widget_actions);
#       body_classlist.add('fixed_actions');
#     }
#   } else {
#     if (body_classlist.contains('fixed_actions')) {
#       widget.style.marginBottom = '';
#       pauseWallpaper(widget_actions);
#       body_classlist.remove('fixed_actions');
#     }
#   }
# }
# function postMessageHandler(event) {
#   try { var data = JSON.parse(event.data); }
#   catch(e) { var data = {}; }
#   if (data.event == 'resize') {
#     setTimeout(checkActionsPosition, 50);
#   }
# }
# if (!CSS || !CSS.supports || !CSS.supports('position', 'sticky') || !IntersectionObserver) {
#   window.addEventListener('resize', checkActionsPosition);
#   window.addEventListener('scroll', checkActionsPosition);
#   window.addEventListener('message', postMessageHandler);
# } else {
#   document.body.classList.add('sticky_actions');
#   var observer = new IntersectionObserver(function(records, observer) {
#     for (var i = 0; i < records.length; i++) {
#       var record = records[i];
#       var widget_actions_wrap = document.getElementById('widget_actions_wrap');
#       var widget_actions = document.getElementById('widget_actions');
#       if (widget_actions_wrap) {
#         pauseWallpaper(widget_actions);
#         widget_actions_wrap.classList.toggle('stuck', !record.isIntersecting);
#       }
#     }
#   }, {threshold: [0], root: document});
#   observer.observe(document.getElementById('widget_actions_helper'));
# }
#
#     </script>
# </body></html>

# %%
results = soup.find_all('div', class_='tgme_widget_message_footer')

# %%
len(results)
# Out:
# 0

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime

post = 'https://t.me/tikvahethiopia/86164'

# Initialize a browser driver (e.g., Chrome)
driver = webdriver.Chrome()

# Load the Telegram post URL
driver.get(post)

# Wait for the iframe to load (adjust the wait time if needed)
driver.implicitly_wait(10)  # Wait up to 10 seconds

# Get the page source after JavaScript execution
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the iframe element
iframe = soup.find('iframe', id='telegram-post-tikvahethiopia-86164')

# Get the iframe source URL
iframe_src = iframe['src']

# Make a new request to the iframe source
iframe_response = requests.get(iframe_src)
iframe_soup = BeautifulSoup(iframe_response.content, 'html.parser')

# Now you can search for the desired elements within iframe_soup
info_div = iframe_soup.find('div', class_='tgme_widget_message_info js-message_info')

# Extract views
views_span = info_div.find('span', class_='tgme_widget_message_views')
views = views_span.text.strip() if views_span else None

# Extract date and time
date_element = info_div.find('a', class_='tgme_widget_message_date')
datetime_element = date_element.find('time', class_='datetime') if date_element else None
date_time = datetime_element['datetime'] if datetime_element else None

# Format the datetime string (only if date_time is not None)
if date_time:
    datetime_object = datetime.fromisoformat(date_time)
    formatted_datetime = datetime_object.strftime('%b %d at %H:%M')

    # Create the dictionary
    data = {
        'Views': [views],
        'Date and Post Hour': [formatted_datetime]
    }

    print(data)
else:
    print("Date and time not found in the iframe.")

# Close the browser driver
driver.quit()
# Out:
# {'Views': ['303.0K'], 'Date and Post Hour': ['Mar 20 at 17:57']}

# %%
from bs4 import BeautifulSoup

html = '<a class="tgme_widget_message_date" href="https://t.me/tikvahethiopia/86164"><time datetime="2024-03-20T17:57:31+00:00" class="datetime">Mar 20 at 20:57</time></a>'
soup = BeautifulSoup(html, 'html.parser')

date_element = soup.find('time', class_='datetime')
date_text = date_element.text.strip()

# Extract month and day from the text
month_day = date_text.split(' at ')[0]

# Assuming the year is the current year, you can construct the full date
import datetime
current_year = datetime.datetime.now().year
date_only = f"{current_year}-{month_day.replace(' ', '-')}"

print(date_only)  # Output: 2024-Mar-20
# Out:
# 2024-Mar-20

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime

post = 'https://t.me/tikvahethiopia/86164'

# Initialize a browser driver (e.g., Chrome)
driver = webdriver.Chrome()

# Load the Telegram post URL
driver.get(post)

# Wait for the iframe to load (adjust the wait time if needed)
driver.implicitly_wait(10)  # Wait up to 10 seconds

# Get the page source after JavaScript execution
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the iframe element
iframe = soup.find('iframe', id='telegram-post-tikvahethiopia-86164')

# Get the iframe source URL
iframe_src = iframe['src']

# Make a new request to the iframe source
iframe_response = requests.get(iframe_src)
iframe_soup = BeautifulSoup(iframe_response.content, 'html.parser')

# Now you can search for the desired elements within iframe_soup
info_div = iframe_soup.find('div', class_='tgme_widget_message_info js-message_info')

# Extract views
views_span = info_div.find('span', class_='tgme_widget_message_views')
views = views_span.text.strip() if views_span else None

# Extract date and time
date_element = info_div.find('a', class_='tgme_widget_message_date')
datetime_element = date_element.find('time', class_='datetime') if date_element else None
date_time = datetime_element['datetime'] if datetime_element else None

# Format the datetime string (only if date_time is not None)
if date_time:
    datetime_object = datetime.fromisoformat(date_time)
    date = datetime_object.strftime('%Y-%m-%d')  # Format date as YYYY-MM-DD
    post_hour = datetime_object.strftime('%H:%M')  # Format time as HH:MM

    # Create the dictionary
    data = {
        'Views': [views],
        'Date': [date],
        'Post Hour': [post_hour]
    }

    print(data)
else:
    print("Date and time not found in the iframe.")

# Close the browser driver
driver.quit()
# Out:
# {'Views': ['303.0K'], 'Date': ['2024-03-20'], 'Post Hour': ['17:57']}

# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import psycopg2

def get_time_of_day(hour):
    if 5 <= hour < 12:
        return 'morning'
    elif 12 <= hour < 17:
        return 'afternoon'
    elif 17 <= hour < 21:
        return 'evening'
    else:
        return 'night'

class PostgresConnection:
    def __init__(self, dbname, user, password, host='localhost', port='5432'):
        self.dbname = dbname
        self.user = user
        self.password = password
        self.host = host
        self.port = port
        self.conn = None
        self.cursor = None

    def connect(self):
        try:
            self.conn = psycopg2.connect(
                dbname=self.dbname,
                user=self.user,
                password=self.password,
                host=self.host,
                port=self.port
            )
            self.cursor = self.conn.cursor()
            print("Connected to PostgreSQL database!")
        except Exception as e:
            print(f"Error: {e}")

    def create_table(self):
        create_table_query = """
        CREATE TABLE IF NOT EXISTS telegram_posts (
            id SERIAL PRIMARY KEY,
            date DATE NOT NULL,
            post_link TEXT NOT NULL,
            view TEXT,
            post_hour TIME,
            bank TEXT,
            time_of_day TEXT
        );
        """
        try:
            self.cursor.execute(create_table_query)
            self.conn.commit()
            print("Table 'telegram_posts' created successfully!")
        except Exception as e:
            print(f"Error creating table: {e}")
            self.conn.rollback()

    def insert_data(self, df, table_name):
        if self.conn is not None:
            try:
                for i, row in df.iterrows():
                    self.cursor.execute(f"""
                        INSERT INTO {table_name} (date, post_link, view, post_hour, bank, time_of_day)
                        VALUES (%s, %s, %s, %s, %s, %s)
                    """, tuple(row))
                self.conn.commit()
                print("Data inserted successfully!")
            except Exception as e:
                print(f"Error: {e}")
                self.conn.rollback()

    def close_connection(self):
        if self.conn is not None:
            self.cursor.close()
            self.conn.close()
            print("Connection closed.")

def extract_data(post_link, bank):
    # Initialize a browser driver (e.g., Chrome)
    driver = webdriver.Chrome()

    # Load the Telegram post URL
    driver.get(post_link)

    # Wait for the iframe to load (adjust the wait time if needed)
    driver.implicitly_wait(10)  # Wait up to 10 seconds

    # Get the page source after JavaScript execution
    html = driver.page_source

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Find the iframe element
    iframe = soup.find('iframe')
    if not iframe:
        print(f"Error: No iframe found for post {post_link}")
        driver.quit()
        return None

    # Get the iframe source URL
    iframe_src = iframe['src']

    # Make a new request to the iframe source
    iframe_response = requests.get(iframe_src)
    iframe_soup = BeautifulSoup(iframe_response.content, 'html.parser')

    # Now you can search for the desired elements within iframe_soup
    info_div = iframe_soup.find('div', class_='tgme_widget_message_info js-message_info')

    # Extract views
    views_span = info_div.find('span', class_='tgme_widget_message_views')
    views = views_span.text.strip() if views_span else None

    # Extract date and time
    date_element = info_div.find('a', class_='tgme_widget_message_date')
    datetime_element = date_element.find('time', class_='datetime') if date_element else None
    date_time = datetime_element['datetime'] if datetime_element else None

    # Close the browser driver
    driver.quit()

    if date_time:
        datetime_object = datetime.fromisoformat(date_time)
        date = datetime_object.strftime('%Y-%m-%d')  # Format date as YYYY-MM-DD
        post_hour = datetime_object.strftime('%H:%M')  # Format time as HH:MM
        time_of_day = get_time_of_day(int(post_hour.split(':')[0]))

        # Create the dictionary
        data = {
            'Views': views,
            'Date': date,
            'Post Hour': post_hour,
            'Bank': bank,
            'Time of Day': time_of_day,
            'Post Link': post_link  # Include the post link
        }

        print(data)
        return data
    else:
        print("Date and time not found in the iframe.")
        return None

# List of posts and associated banks
posts = [
    {'post_link': 'https://t.me/tikvahethiopia/86164', 'bank': 'CBE'},
    {'post_link': 'https://t.me/tikvahethiopia/87041', 'bank': 'GBE'},
    {'post_link': 'https://t.me/tikvahethiopia/86185', 'bank': 'GBE'},
    {'post_link': 'https://t.me/tikvahethiopia/87532', 'bank': 'BOA'}
]

# Extract data and insert into PostgreSQL
db = PostgresConnection(dbname='bank', user='postgres', password='Mati@1993')
db.connect()
db.create_table()  # Ensure the table exists before inserting data

for post in posts:
    extracted_data = extract_data(post['post_link'], post['bank'])
    if extracted_data:
        # Create DataFrame
        data = {
            'date': [extracted_data['Date']],
            'post_link': [extracted_data['Post Link']],
            'view': [extracted_data['Views']],
            'post_hour': [extracted_data['Post Hour']],
            'bank': [extracted_data['Bank']],
            'time_of_day': [extracted_data['Time of Day']]
        }
        df = pd.DataFrame(data)

        # Insert data into PostgreSQL
        db.insert_data(df, 'telegram_posts')

db.close_connection()
# Out:
# Connected to PostgreSQL database!
# Table 'telegram_posts' created successfully!
# {'Views': '303.0K', 'Date': '2024-03-20', 'Post Hour': '17:57', 'Bank': 'CBE', 'Time of Day': 'evening', 'Post Link': 'https://t.me/tikvahethiopia/86164'}
# Data inserted successfully!
# {'Views': '281.7K', 'Date': '2024-04-20', 'Post Hour': '15:48', 'Bank': 'GBE', 'Time of Day': 'afternoon', 'Post Link': 'https://t.me/tikvahethiopia/87041'}
# Data inserted successfully!
# {'Views': '265.7K', 'Date': '2024-03-21', 'Post Hour': '14:15', 'Bank': 'GBE', 'Time of Day': 'afternoon', 'Post Link': 'https://t.me/tikvahethiopia/86185'}
# Data inserted successfully!
# {'Views': '278.7K', 'Date': '2024-05-10', 'Post Hour': '13:39', 'Bank': 'BOA', 'Time of Day': 'afternoon', 'Post Link': 'https://t.me/tikvahethiopia/87532'}
# Data inserted successfully!
# Connection closed.
